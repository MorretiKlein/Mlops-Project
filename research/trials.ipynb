# %%
def deco(func):
    def wrapper():
        print("This will get printed before the function is called.")
        func()
        print("This will get printed after the function is called.")

    return wrapper

# %%
def ans():
    print(42)
b = deco(ans)
b()
# Out:
# This will get printed before the function is called.
# 42
# This will get printed after the function is called.

# %%
d = {"key": "value", "key1": "value1"}
d["key"]
# Out:
# 'value'

# %%
from box import ConfigBox
d2 = ConfigBox({"key": "value", "key1": "value1"})
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key # so it's easy to reach
# Out:
# 'value'

# %%
def calculate( x: int, y : int) -> int:
    return x * y
print(calculate(2,4))
print(calculate(2,"4"))
# Out:
# 8
# 44

# %%
from ensure import ensure_annotations
@ensure_annotations
def calculate( x: int, y : int) -> int:
    return x * y
print(calculate(2,4))
# print(calculate(2,"4")) # nó sẽ báo lỗi don't match annotation type
# Out:
# 8

# %%
import os

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\Project\\P\\Mlops-Project'

# %%
import cv2
import torch

# %%
model_path = 'evaluation/weights/best.pt'
model = torch.load(model_path)

# %%
model
# Out:
# {'epoch': -1,
#  'best_fitness': None,
#  'model': DetectionModel(
#    (model): Sequential(
#      (0): Conv(
#        (conv): Conv2d(3, 16, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2), bias=False)
#        (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#      )
#      (1): Conv(
#        (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#      )
#      (2): C3(
#        (cv1): Conv(
#          (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (cv2): Conv(
#          (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
import cv2
from ultralytics import YOLO

model_path = 'evaluation/weights/best.pt'
model = YOLO(model_path)
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    results = model.predict(frame)
    
    if results[0].boxes is not None:
        boxes = results[0].boxes.xyxy
        for boxs in range(len(boxes)):
            bbox = boxs.cpu().numpy()  
            [x1, y1, x2, y2]  = boxes
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # Chuyển đổi sang kiểu số nguyên
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, f"person", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    cv2.imshow('person Prediction', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 85.7ms
# Speed: 15.0ms preprocess, 85.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([[  6.3129,   0.0000, 634.3486, 480.0000]])

# %%
import cv2
from ultralytics import YOLO

model_path = 'evaluation/weights/best.pt'
model = YOLO(model_path)

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    results = model.predict(frame)
    
    if results[0].boxes is not None:  
        for box in results[0].boxes.xyxy:
            x1, y1, x2, y2 = int(box[0]), int(box[1]), int(box[2]), int(box[3]) 
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)  
            cv2.putText(frame, f"person", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2) 

    cv2.imshow('person Prediction', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 102.7ms
# Speed: 11.5ms preprocess, 102.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.8ms
# Speed: 4.2ms preprocess, 160.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 150.8ms
# Speed: 3.7ms preprocess, 150.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.7ms
# Speed: 4.0ms preprocess, 162.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.9ms
# Speed: 1.0ms preprocess, 88.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.5ms
# Speed: 2.0ms preprocess, 107.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.1ms
# Speed: 2.5ms preprocess, 119.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.9ms
# ...

# %%
0: 480x640 1 person, 103.1ms

    print('a')
    print(results[0].boxes.xyxy[0][0])

Speed: 7.8ms preprocess, 103.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
[ultralytics.engine.results.Results object with attributes:

boxes: ultralytics.engine.results.Boxes object
keypoints: None
masks: None
names: {0: 'person'}
orig_img: array([[[161, 243, 255],
        [173, 242, 255],
        [182, 239, 255],
        ...,
        [255, 255, 255],
        [255, 255, 255],
        [255, 255, 255]],

       [[167, 244, 255],
        [175, 242, 255],
        [183, 240, 255],
        ...,
        [255, 255, 255],
        [255, 255, 255],
        [255, 255, 255]],
...
path: 'image0.jpg'
probs: None
save_dir: None
speed: {'preprocess': 7.833719253540039, 'inference': 103.12175750732422, 'postprocess': 0.0}]
